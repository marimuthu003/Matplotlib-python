# %%
from itertools import count
import random
from matplotlib import pyplot as plt
plt.ion
from matplotlib.animation import FuncAnimation


plt.style.use('fivethirtyeight')

fig,ax1=plt.subplots()
x_vals = []
y_vals = []


# to count the numbers from 1:
index = count()

def animate(i):
   
    x_vals.append(next(index))
    y_vals.append(random.randint(0, 5))
    ax1.clear()  # Clear the previous plot
    # plot these values
    ax1.plot(x_vals, y_vals)

ani = FuncAnimation(fig, animate, interval=1000,cache_frame_data=False)

# Display the animation in Jupyter Notebook
from IPython.display import HTML
HTML(ani.to_jshtml())

fig.tight_layout()

plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 30
#      28 # Display the animation in Jupyter Notebook
#      29 from IPython.display import HTML
# ---> 30 HTML(ani.to_jshtml())
#      32 fig.tight_layout()
#      34 plt.show()
#
# File d:\Muthu\matplotlib-python\venv2\Lib\site-packages\matplotlib\animation.py:1353, in Animation.to_jshtml(self, fps, embed_frames, default_mode)
#    1349         path = Path(tmpdir, "temp.html")
#    1350         writer = HTMLWriter(fps=fps,
#    1351                             embed_frames=embed_frames,
#    1352                             default_mode=default_mode)
# -> 1353         self.save(str(path), writer=writer)
#    1354         self._html_representation = path.read_text()
#    1356 return self._html_representation
#
# File d:\Muthu\matplotlib-python\venv2\Lib\site-packages\matplotlib\animation.py:1105, in Animation.save(self, filename, writer, fps, dpi, codec, bitrate, extra_args, metadata, extra_anim, savefig_kwargs, progress_callback)
#    1102 for data in zip(*[a.new_saved_frame_seq() for a in all_anim]):
#    1103     for anim, d in zip(all_anim, data):
#    1104         # TODO: See if turning off blit is really necessary
# -> 1105         anim._draw_next_frame(d, blit=False)
#    1106         if progress_callback is not None:
#    1107             progress_callback(frame_number, total_frames)
#
# File d:\Muthu\matplotlib-python\venv2\Lib\site-packages\matplotlib\animation.py:1141, in Animation._draw_next_frame(self, framedata, blit)
#    1139 self._pre_draw(framedata, blit)
#    1140 self._draw_frame(framedata)
# -> 1141 self._post_draw(framedata, blit)
#
# File d:\Muthu\matplotlib-python\venv2\Lib\site-packages\matplotlib\animation.py:1166, in Animation._post_draw(self, framedata, blit)
#    1164     self._blit_draw(self._drawn_artists)
#    1165 else:
# -> 1166     self._fig.canvas.draw_idle()
#
# File d:\Muthu\matplotlib-python\venv2\Lib\site-packages\matplotlib\backend_bases.py:1893, in FigureCanvasBase.draw_idle(self, *args, **kwargs)
#    1891 if not self._is_idle_drawing:
#    1892     with self._idle_draw_cntx():
# -> 1893         self.draw(*args, **kwargs)
#
# File d:\Muthu\matplotlib-python\venv2\Lib\site-packages\matplotlib\backends\backend_agg.py:388, in FigureCanvasAgg.draw(self)
#     385 # Acquire a lock on the shared font cache.
#     386 with (self.toolbar._wait_cursor_for_draw_cm() if self.toolbar
#     387       else nullcontext()):
# --> 388     self.figure.draw(self.renderer)
#     389     # A GUI class may be need to update a window using this draw, so
#     390     # don't forget to call the superclass.
#     391     super().draw()
#
# File d:\Muthu\matplotlib-python\venv2\Lib\site-packages\matplotlib\artist.py:95, in _finalize_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      93 @wraps(draw)
#      94 def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 95     result = draw(artist, renderer, *args, **kwargs)
#      96     if renderer._rasterizing:
#      97         renderer.stop_rasterizing()
#
# File d:\Muthu\matplotlib-python\venv2\Lib\site-packages\matplotlib\artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File d:\Muthu\matplotlib-python\venv2\Lib\site-packages\matplotlib\figure.py:3153, in Figure.draw(self, renderer)
#    3150         pass
#    3151         # ValueError can occur when resizing a window.
# -> 3153 self.patch.draw(renderer)
#    3154 mimage._draw_list_compositing_images(
#    3155     renderer, self, artists, self.suppressComposite)
#    3157 for sfig in self.subfigs:
#
# File d:\Muthu\matplotlib-python\venv2\Lib\site-packages\matplotlib\artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File d:\Muthu\matplotlib-python\venv2\Lib\site-packages\matplotlib\patches.py:585, in Patch.draw(self, renderer)
#     583     return
#     584 path = self.get_path()
# --> 585 transform = self.get_transform()
#     586 tpath = transform.transform_path_non_affine(path)
#     587 affine = transform.get_affine()
#
# File d:\Muthu\matplotlib-python\venv2\Lib\site-packages\matplotlib\patches.py:261, in Patch.get_transform(self)
#     259 def get_transform(self):
#     260     """Return the `~.transforms.Transform` applied to the `Patch`."""
# --> 261     return self.get_patch_transform() + artist.Artist.get_transform(self)
#
# File d:\Muthu\matplotlib-python\venv2\Lib\site-packages\matplotlib\patches.py:751, in Rectangle.get_patch_transform(self)
#     746 def get_patch_transform(self):
#     747     # Note: This cannot be called until after this has been added to
#     748     # an Axes, otherwise unit conversion will fail. This makes it very
#     749     # important to call the accessor method and not directly access the
#     750     # transformation member variable.
# --> 751     bbox = self.get_bbox()
#     752     if self.rotation_point == 'center':
#     753         width, height = bbox.x1 - bbox.x0, bbox.y1 - bbox.y0
#
# File d:\Muthu\matplotlib-python\venv2\Lib\site-packages\matplotlib\patches.py:882, in Rectangle.get_bbox(self)
#     880 def get_bbox(self):
#     881     """Return the `.Bbox`."""
# --> 882     return transforms.Bbox.from_extents(*self._convert_units())
#
# File d:\Muthu\matplotlib-python\venv2\Lib\site-packages\matplotlib\transforms.py:829, in Bbox.from_extents(minpos, *args)
#     813 @staticmethod
#     814 def from_extents(*args, minpos=None):
#     815     """
#     816     Create a new Bbox from *left*, *bottom*, *right* and *top*.
#     817
#    (...)
#     827         scales where negative bounds result in floating point errors.
#     828     """
# --> 829     bbox = Bbox(np.reshape(args, (2, 2)))
#     830     if minpos is not None:
#     831         bbox._minpos[:] = minpos
#
# File d:\Muthu\matplotlib-python\venv2\Lib\site-packages\matplotlib\transforms.py:776, in Bbox.__init__(self, points, **kwargs)
#     772 self._ignore = True
#     773 # it is helpful in some contexts to know if the bbox is a
#     774 # default or has been mutated; we store the orig points to
#     775 # support the mutated methods
# --> 776 self._points_orig = self._points.copy()
#
# KeyboardInterrupt:

# %%
from itertools import count
import random
from matplotlib import pyplot as plt
from matplotlib.animation import FuncAnimation

plt.style.use('fivethirtyeight')

x_vals = []
y_vals = []

# to count the numbers from 1:
index = count()

def animate(i):
    x_vals.append(next(index))
    y_vals.append(random.randint(0, 5))
    
    plt.clf()  # Clear the entire current figure
    
    # plot these values
    plt.plot(x_vals, y_vals)

ani = FuncAnimation(plt.gcf(), animate, interval=1000, cache_frame_data=False)

# Assign the animation object to a variable
anim_reference = ani

plt.tight_layout()

# Show the animation
plt.show()
# Out:
# d:\Muthu\matplotlib-python\venv2\Lib\site-packages\matplotlib\animation.py:892: UserWarning: Animation was deleted without rendering anything. This is most likely not intended. To prevent deletion, assign the Animation to a variable, e.g. `anim`, that exists until you output the Animation using `plt.show()` or `anim.save()`.
#   warnings.warn(
